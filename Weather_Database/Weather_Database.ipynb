# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
        
#"Current Description": city_weather_description
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | otjiwarongo
# Processing Record 4 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 1 | taiyuan
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | price
# Processing Record 10 of Set 1 | albanel
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | paraiso
# Processing Record 13 of Set 1 | bathsheba
# Processing Record 14 of Set 1 | krasnovishersk
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | gravdal
# Processing Record 18 of Set 1 | najran
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | banmo
# City not found. Skipping...
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | palmer
# Processing Record 24 of Set 1 | luderitz
# Processing Record 25 of Set 1 | belaya gora
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | riyadh
# Processing Record 29 of Set 1 | hasaki
# Processing Record 30 of Set 1 | vung tau
# Processing Record 31 of Set 1 | tabuk
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | thaba nchu
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | kamaishi
# Processing Record 43 of Set 1 | kralendijk
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | ozernovskiy
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | yenagoa
# Processing Record 1 of Set 2 | san carlos del zulia
# Processing Record 2 of Set 2 | inhambane
# Processing Record 3 of Set 2 | jalu
# Processing Record 4 of Set 2 | marrakesh
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | aduturai
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | marsh harbour
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | lubbecke
# Processing Record 17 of Set 2 | san policarpo
# Processing Record 18 of Set 2 | nizhnevartovsk
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 2 | gogrial
# Processing Record 25 of Set 2 | chitrakonda
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | sorland
# Processing Record 28 of Set 2 | khalkhal
# Processing Record 29 of Set 2 | caravelas
# Processing Record 30 of Set 2 | geraldton
# Processing Record 31 of Set 2 | inverness
# Processing Record 32 of Set 2 | heishan
# Processing Record 33 of Set 2 | ancud
# Processing Record 34 of Set 2 | yavaros
# Processing Record 35 of Set 2 | srednekolymsk
# Processing Record 36 of Set 2 | vostok
# Processing Record 37 of Set 2 | samfya
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | talnakh
# Processing Record 40 of Set 2 | ust-kuyga
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | villa vazquez
# City not found. Skipping...
# Processing Record 43 of Set 2 | makat
# Processing Record 44 of Set 2 | tecoanapa
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | northam
# Processing Record 47 of Set 2 | portland
# Processing Record 48 of Set 2 | namatanai
# Processing Record 49 of Set 2 | constitucion
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | lavrentiya
# Processing Record 4 of Set 3 | kodiak
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | goma
# Processing Record 7 of Set 3 | port hardy
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | tautira
# Processing Record 11 of Set 3 | katsuura
# Processing Record 12 of Set 3 | burnie
# Processing Record 13 of Set 3 | mount gambier
# Processing Record 14 of Set 3 | nizhniy odes
# Processing Record 15 of Set 3 | alice springs
# Processing Record 16 of Set 3 | potchefstroom
# Processing Record 17 of Set 3 | berlevag
# Processing Record 18 of Set 3 | avrille
# Processing Record 19 of Set 3 | merauke
# Processing Record 20 of Set 3 | punta arenas
# Processing Record 21 of Set 3 | lagoa
# Processing Record 22 of Set 3 | prince rupert
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 | dunedin
# Processing Record 25 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 3 | havre-saint-pierre
# Processing Record 27 of Set 3 | sakakah
# Processing Record 28 of Set 3 | salalah
# Processing Record 29 of Set 3 | provost
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | bandarbeyla
# Processing Record 32 of Set 3 | grindavik
# Processing Record 33 of Set 3 | angoche
# Processing Record 34 of Set 3 | san mateo
# Processing Record 35 of Set 3 | vilhena
# Processing Record 36 of Set 3 | sao gabriel da cachoeira
# Processing Record 37 of Set 3 | hilo
# Processing Record 38 of Set 3 | jamame
# Processing Record 39 of Set 3 | natal
# Processing Record 40 of Set 3 | aklavik
# Processing Record 41 of Set 3 | leningradskiy
# Processing Record 42 of Set 3 | ouesso
# Processing Record 43 of Set 3 | safwah
# City not found. Skipping...
# Processing Record 44 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 3 | turukhansk
# Processing Record 46 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 3 | shingu
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 4 | buala
# Processing Record 3 of Set 4 | xiangdong
# City not found. Skipping...
# Processing Record 4 of Set 4 | safaga
# Processing Record 5 of Set 4 | cabo san lucas
# Processing Record 6 of Set 4 | del rio
# Processing Record 7 of Set 4 | la ronge
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | lazaro cardenas
# Processing Record 10 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | zavodoukovsk
# Processing Record 13 of Set 4 | saint-augustin
# Processing Record 14 of Set 4 | sharjah
# Processing Record 15 of Set 4 | cayenne
# Processing Record 16 of Set 4 | clarence town
# Processing Record 17 of Set 4 | leh
# Processing Record 18 of Set 4 | viedma
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | tasiilaq
# Processing Record 21 of Set 4 | gemena
# Processing Record 22 of Set 4 | saint george
# Processing Record 23 of Set 4 | kalmunai
# Processing Record 24 of Set 4 | guerrero
# Processing Record 25 of Set 4 | butaritari
# Processing Record 26 of Set 4 | patan
# Processing Record 27 of Set 4 | asau
# Processing Record 28 of Set 4 | san cristobal
# Processing Record 29 of Set 4 | honningsvag
# Processing Record 30 of Set 4 | thinadhoo
# Processing Record 31 of Set 4 | carauari
# Processing Record 32 of Set 4 | marystown
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | poum
# Processing Record 35 of Set 4 | whitianga
# Processing Record 36 of Set 4 | lunenburg
# Processing Record 37 of Set 4 | awjilah
# Processing Record 38 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 4 | aporawan
# City not found. Skipping...
# Processing Record 40 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 4 | zhezkazgan
# Processing Record 42 of Set 4 | nishihara
# Processing Record 43 of Set 4 | solnechnyy
# Processing Record 44 of Set 4 | mahebourg
# Processing Record 45 of Set 4 | sztum
# Processing Record 46 of Set 4 | san quintin
# Processing Record 47 of Set 4 | hami
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | svetlyy yar
# Processing Record 50 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 5 | goderich
# Processing Record 2 of Set 5 | omsukchan
# Processing Record 3 of Set 5 | jiuquan
# Processing Record 4 of Set 5 | kokopo
# Processing Record 5 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 5 | aykhal
# Processing Record 7 of Set 5 | ostersund
# Processing Record 8 of Set 5 | bejar
# Processing Record 9 of Set 5 | panaba
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | huazolotitlan
# City not found. Skipping...
# Processing Record 13 of Set 5 | clyde river
# Processing Record 14 of Set 5 | malayal
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | port macquarie
# Processing Record 17 of Set 5 | tiksi
# Processing Record 18 of Set 5 | guiren
# Processing Record 19 of Set 5 | nicoya
# Processing Record 20 of Set 5 | ribeira grande
# Processing Record 21 of Set 5 | coquimbo
# Processing Record 22 of Set 5 | mar del plata
# Processing Record 23 of Set 5 | dalvik
# Processing Record 24 of Set 5 | poquoson
# Processing Record 25 of Set 5 | addi ugri
# City not found. Skipping...
# Processing Record 26 of Set 5 | tornio
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | ca mau
# Processing Record 29 of Set 5 | oistins
# Processing Record 30 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 31 of Set 5 | mackenzie
# Processing Record 32 of Set 5 | san patricio
# Processing Record 33 of Set 5 | wilmington
# Processing Record 34 of Set 5 | leeton
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | flinders
# Processing Record 37 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 5 | bud
# Processing Record 39 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 5 | bayir
# Processing Record 41 of Set 5 | whitehorse
# Processing Record 42 of Set 5 | santa maria
# Processing Record 43 of Set 5 | twin falls
# Processing Record 44 of Set 5 | praia da vitoria
# Processing Record 45 of Set 5 | ponta do sol
# Processing Record 46 of Set 5 | itarema
# Processing Record 47 of Set 5 | auch
# Processing Record 48 of Set 5 | daru
# Processing Record 49 of Set 5 | ishigaki
# Processing Record 50 of Set 5 | nhulunbuy
# Processing Record 1 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 6 | quatre cocos
# Processing Record 3 of Set 6 | mae hong son
# Processing Record 4 of Set 6 | nabire
# Processing Record 5 of Set 6 | san ignacio
# Processing Record 6 of Set 6 | edd
# Processing Record 7 of Set 6 | sinnamary
# Processing Record 8 of Set 6 | araouane
# Processing Record 9 of Set 6 | olafsvik
# Processing Record 10 of Set 6 | tall kayf
# Processing Record 11 of Set 6 | tahta
# Processing Record 12 of Set 6 | sitka
# Processing Record 13 of Set 6 | sunbury
# Processing Record 14 of Set 6 | seoul
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 6 | norman wells
# Processing Record 18 of Set 6 | ambon
# Processing Record 19 of Set 6 | otane
# Processing Record 20 of Set 6 | labuhan
# Processing Record 21 of Set 6 | gorin
# Processing Record 22 of Set 6 | mercedes
# Processing Record 23 of Set 6 | chojnow
# Processing Record 24 of Set 6 | sao miguel do araguaia
# Processing Record 25 of Set 6 | saint-leu
# Processing Record 26 of Set 6 | alofi
# Processing Record 27 of Set 6 | saint anthony
# Processing Record 28 of Set 6 | berdigestyakh
# Processing Record 29 of Set 6 | bognor regis
# Processing Record 30 of Set 6 | mackay
# Processing Record 31 of Set 6 | marawi
# Processing Record 32 of Set 6 | saint-pierre
# Processing Record 33 of Set 6 | brae
# Processing Record 34 of Set 6 | khandyga
# Processing Record 35 of Set 6 | lompoc
# Processing Record 36 of Set 6 | conakry
# Processing Record 37 of Set 6 | taylorville
# Processing Record 38 of Set 6 | barra do garcas
# Processing Record 39 of Set 6 | provideniya
# Processing Record 40 of Set 6 | stokmarknes
# Processing Record 41 of Set 6 | qaqortoq
# Processing Record 42 of Set 6 | eirunepe
# Processing Record 43 of Set 6 | kenai
# Processing Record 44 of Set 6 | healdsburg
# Processing Record 45 of Set 6 | ayan
# Processing Record 46 of Set 6 | sao filipe
# Processing Record 47 of Set 6 | jucurutu
# Processing Record 48 of Set 6 | lasa
# Processing Record 49 of Set 6 | sorong
# Processing Record 50 of Set 6 | wuwei
# Processing Record 1 of Set 7 | bayan
# Processing Record 2 of Set 7 | mecca
# Processing Record 3 of Set 7 | komsomolskiy
# Processing Record 4 of Set 7 | kibondo
# Processing Record 5 of Set 7 | staraya mayna
# Processing Record 6 of Set 7 | dwarka
# Processing Record 7 of Set 7 | ipojuca
# Processing Record 8 of Set 7 | pembroke
# Processing Record 9 of Set 7 | muzhi
# Processing Record 10 of Set 7 | torbay
# Processing Record 11 of Set 7 | olinda
# Processing Record 12 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 7 | roebourne
# Processing Record 14 of Set 7 | vao
# Processing Record 15 of Set 7 | vanimo
# Processing Record 16 of Set 7 | marialva
# Processing Record 17 of Set 7 | bara
# Processing Record 18 of Set 7 | mocuba
# Processing Record 19 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 7 | harper
# Processing Record 21 of Set 7 | sulangan
# Processing Record 22 of Set 7 | hamilton
# Processing Record 23 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 24 of Set 7 | airai
# Processing Record 25 of Set 7 | sampit
# Processing Record 26 of Set 7 | meulaboh
# Processing Record 27 of Set 7 | santiago del estero
# Processing Record 28 of Set 7 | upernavik
# Processing Record 29 of Set 7 | fare
# Processing Record 30 of Set 7 | port elizabeth
# Processing Record 31 of Set 7 | sibolga
# Processing Record 32 of Set 7 | belfort
# Processing Record 33 of Set 7 | domoni
# Processing Record 34 of Set 7 | ust-kut
# Processing Record 35 of Set 7 | gigmoto
# Processing Record 36 of Set 7 | gemona
# Processing Record 37 of Set 7 | kendari
# Processing Record 38 of Set 7 | richards bay
# Processing Record 39 of Set 7 | tulagi
# Processing Record 40 of Set 7 | lulea
# Processing Record 41 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 7 | evensk
# Processing Record 43 of Set 7 | muroto
# Processing Record 44 of Set 7 | ruthin
# Processing Record 45 of Set 7 | amuntai
# Processing Record 46 of Set 7 | camacupa
# Processing Record 47 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 7 | bilma
# Processing Record 49 of Set 7 | rozhdestveno
# Processing Record 50 of Set 7 | aripuana
# Processing Record 1 of Set 8 | makakilo city
# Processing Record 2 of Set 8 | saint-joseph
# Processing Record 3 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 8 | nemuro
# Processing Record 5 of Set 8 | hambantota
# Processing Record 6 of Set 8 | wexford
# Processing Record 7 of Set 8 | half moon bay
# Processing Record 8 of Set 8 | xacmaz
# Processing Record 9 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 8 | rioja
# Processing Record 11 of Set 8 | cape coast
# Processing Record 12 of Set 8 | beringovskiy
# Processing Record 13 of Set 8 | torfyanoy
# Processing Record 14 of Set 8 | vallenar
# Processing Record 15 of Set 8 | koumac
# Processing Record 16 of Set 8 | maiduguri
# Processing Record 17 of Set 8 | baruun-urt
# Processing Record 18 of Set 8 | atambua
# Processing Record 19 of Set 8 | coihaique
# Processing Record 20 of Set 8 | santa marta de tormes
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | klyuchi
# Processing Record 23 of Set 8 | maragogi
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | orange
# Processing Record 26 of Set 8 | emerald
# Processing Record 27 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 8 | kayerkan
# Processing Record 29 of Set 8 | manggar
# Processing Record 30 of Set 8 | the valley
# Processing Record 31 of Set 8 | loandjili
# Processing Record 32 of Set 8 | kattivakkam
# Processing Record 33 of Set 8 | manaus
# Processing Record 34 of Set 8 | san marcos de colon
# Processing Record 35 of Set 8 | faya
# Processing Record 36 of Set 8 | san vicente
# Processing Record 37 of Set 8 | kurmanayevka
# Processing Record 38 of Set 8 | tessalit
# Processing Record 39 of Set 8 | mari-turek
# Processing Record 40 of Set 8 | guerrero negro
# Processing Record 41 of Set 8 | markova
# Processing Record 42 of Set 8 | lata
# Processing Record 43 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 8 | husavik
# Processing Record 45 of Set 8 | monroe
# Processing Record 46 of Set 8 | maceio
# Processing Record 47 of Set 8 | ilulissat
# Processing Record 48 of Set 8 | salumbar
# Processing Record 49 of Set 8 | moose factory
# Processing Record 50 of Set 8 | santa isabel do rio negro
# Processing Record 1 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 9 | hillsborough
# Processing Record 3 of Set 9 | kantang
# Processing Record 4 of Set 9 | mayumba
# Processing Record 5 of Set 9 | konevo
# Processing Record 6 of Set 9 | kirakira
# Processing Record 7 of Set 9 | nautla
# Processing Record 8 of Set 9 | mitsamiouli
# Processing Record 9 of Set 9 | sirsilla
# Processing Record 10 of Set 9 | burns lake
# Processing Record 11 of Set 9 | maningrida
# Processing Record 12 of Set 9 | acarau
# Processing Record 13 of Set 9 | linfen
# Processing Record 14 of Set 9 | fuerte olimpo
# Processing Record 15 of Set 9 | bermeo
# Processing Record 16 of Set 9 | goulburn
# Processing Record 17 of Set 9 | hazorasp
# Processing Record 18 of Set 9 | port blair
# Processing Record 19 of Set 9 | mehamn
# Processing Record 20 of Set 9 | shimoda
# Processing Record 21 of Set 9 | tra vinh
# Processing Record 22 of Set 9 | xiangxiang
# Processing Record 23 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 9 | darhan
# Processing Record 25 of Set 9 | kloulklubed
# Processing Record 26 of Set 9 | pangnirtung
# Processing Record 27 of Set 9 | marsta
# Processing Record 28 of Set 9 | gizo
# Processing Record 29 of Set 9 | malanje
# Processing Record 30 of Set 9 | georgetown
# Processing Record 31 of Set 9 | brookhaven
# Processing Record 32 of Set 9 | thomasville
# Processing Record 33 of Set 9 | batagay
# Processing Record 34 of Set 9 | ciudad guayana
# Processing Record 35 of Set 9 | kavaratti
# Processing Record 36 of Set 9 | yaqui
# Processing Record 37 of Set 9 | taketa
# Processing Record 38 of Set 9 | aswan
# Processing Record 39 of Set 9 | ulety
# Processing Record 40 of Set 9 | nantucket
# Processing Record 41 of Set 9 | port lincoln
# Processing Record 42 of Set 9 | abnub
# Processing Record 43 of Set 9 | henties bay
# Processing Record 44 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 9 | puri
# Processing Record 46 of Set 9 | charlottetown
# Processing Record 47 of Set 9 | rocha
# Processing Record 48 of Set 9 | broome
# Processing Record 49 of Set 9 | iquitos
# Processing Record 50 of Set 9 | warrnambool
# Processing Record 1 of Set 10 | bubaque
# Processing Record 2 of Set 10 | senekal
# Processing Record 3 of Set 10 | araceli
# Processing Record 4 of Set 10 | kahului
# Processing Record 5 of Set 10 | gra liyia
# Processing Record 6 of Set 10 | sur
# Processing Record 7 of Set 10 | russkaya polyana
# Processing Record 8 of Set 10 | north bend
# Processing Record 9 of Set 10 | terrytown
# Processing Record 10 of Set 10 | burlington
# Processing Record 11 of Set 10 | octeville
# Processing Record 12 of Set 10 | kibaek
# Processing Record 13 of Set 10 | bairiki
# Processing Record 14 of Set 10 | gorey
# Processing Record 15 of Set 10 | vardo
# Processing Record 16 of Set 10 | tshela
# Processing Record 17 of Set 10 | karratha
# Processing Record 18 of Set 10 | barcelos
# Processing Record 19 of Set 10 | charlestown
# Processing Record 20 of Set 10 | khasan
# Processing Record 21 of Set 10 | zhovtneve
# Processing Record 22 of Set 10 | goundam
# Processing Record 23 of Set 10 | souillac
# Processing Record 24 of Set 10 | cockburn town
# Processing Record 25 of Set 10 | la seyne-sur-mer
# Processing Record 26 of Set 10 | kargasok
# Processing Record 27 of Set 10 | anadyr
# Processing Record 28 of Set 10 | ponta delgada
# Processing Record 29 of Set 10 | havelock
# Processing Record 30 of Set 10 | malatya
# Processing Record 31 of Set 10 | poronaysk
# Processing Record 32 of Set 10 | majene
# Processing Record 33 of Set 10 | dicabisagan
# Processing Record 34 of Set 10 | yar-sale
# Processing Record 35 of Set 10 | sibu
# Processing Record 36 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 37 of Set 10 | isfana
# Processing Record 38 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 39 of Set 10 | qui nhon
# Processing Record 40 of Set 10 | urdoma
# Processing Record 41 of Set 10 | moron
# Processing Record 42 of Set 10 | janauba
# Processing Record 43 of Set 10 | kavieng
# Processing Record 44 of Set 10 | kembe
# Processing Record 45 of Set 10 | dingle
# Processing Record 46 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 47 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 10 | juneau
# Processing Record 49 of Set 10 | kasangulu
# Processing Record 50 of Set 10 | camocim
# Processing Record 1 of Set 11 | esfarayen
# Processing Record 2 of Set 11 | miri
# Processing Record 3 of Set 11 | timra
# Processing Record 4 of Set 11 | makaha
# Processing Record 5 of Set 11 | cidreira
# Processing Record 6 of Set 11 | saposoa
# Processing Record 7 of Set 11 | san carlos de bariloche
# Processing Record 8 of Set 11 | pangkalanbuun
# Processing Record 9 of Set 11 | batemans bay
# Processing Record 10 of Set 11 | bundaberg
# Processing Record 11 of Set 11 | alihe
# Processing Record 12 of Set 11 | fort nelson
# Processing Record 13 of Set 11 | puerto escondido
# Processing Record 14 of Set 11 | bogovinje
# Processing Record 15 of Set 11 | odweyne
# Processing Record 16 of Set 11 | yumen
# Processing Record 17 of Set 11 | muriti
# Processing Record 18 of Set 11 | benguela
# Processing Record 19 of Set 11 | camapua
# Processing Record 20 of Set 11 | namanga
# Processing Record 21 of Set 11 | carrickfergus
# Processing Record 22 of Set 11 | valparaiso
# Processing Record 23 of Set 11 | lingao
# Processing Record 24 of Set 11 | inta
# Processing Record 25 of Set 11 | hofn
# Processing Record 26 of Set 11 | arlit
# Processing Record 27 of Set 11 | goure
# Processing Record 28 of Set 11 | saipipi
# City not found. Skipping...
# Processing Record 29 of Set 11 | vestmannaeyjar
# Processing Record 30 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 11 | kondinskoye
# Processing Record 32 of Set 11 | padang
# Processing Record 33 of Set 11 | avera
# Processing Record 34 of Set 11 | marfino
# Processing Record 35 of Set 11 | haldensleben
# Processing Record 36 of Set 11 | san-pedro
# Processing Record 37 of Set 11 | koslan
# Processing Record 38 of Set 11 | yaan
# Processing Record 39 of Set 11 | jiutai
# Processing Record 40 of Set 11 | cap malheureux
# Processing Record 41 of Set 11 | tianpeng
# Processing Record 42 of Set 11 | vershino-shakhtaminskiy
# Processing Record 43 of Set 11 | tatvan
# Processing Record 44 of Set 11 | pendleton
# Processing Record 45 of Set 11 | mengcheng
# Processing Record 46 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 11 | mezen
# Processing Record 48 of Set 11 | gualaquiza
# Processing Record 49 of Set 11 | tagusao
# Processing Record 50 of Set 11 | uchiza
# Processing Record 1 of Set 12 | general roca
# Processing Record 2 of Set 12 | itaituba
# Processing Record 3 of Set 12 | pingliang
# Processing Record 4 of Set 12 | fort collins
# Processing Record 5 of Set 12 | muromtsevo
# Processing Record 6 of Set 12 | damghan
# Processing Record 7 of Set 12 | terrace
# Processing Record 8 of Set 12 | mubende
# Processing Record 9 of Set 12 | filadelfia
# Processing Record 10 of Set 12 | atar
# Processing Record 11 of Set 12 | aranda de duero
# Processing Record 12 of Set 12 | diamantino
# Processing Record 13 of Set 12 | sangar
# Processing Record 14 of Set 12 | esperance
# Processing Record 15 of Set 12 | macau
# Processing Record 16 of Set 12 | esna
# Processing Record 17 of Set 12 | gryazovets
# Processing Record 18 of Set 12 | kushmurun
# Processing Record 19 of Set 12 | bereda
# Processing Record 20 of Set 12 | yabelo
# Processing Record 21 of Set 12 | kamen-rybolov
# Processing Record 22 of Set 12 | coihueco
# Processing Record 23 of Set 12 | turka
# Processing Record 24 of Set 12 | vestmanna
# Processing Record 25 of Set 12 | samarai
# Processing Record 26 of Set 12 | barahona
# Processing Record 27 of Set 12 | nyurba
# Processing Record 28 of Set 12 | namibe
# Processing Record 29 of Set 12 | rio grande
# Processing Record 30 of Set 12 | jumla
# Processing Record 31 of Set 12 | abu samrah
# Processing Record 32 of Set 12 | joshimath
# Processing Record 33 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 12 | kerrville
# Processing Record 35 of Set 12 | phalaborwa
# Processing Record 36 of Set 12 | boende
# Processing Record 37 of Set 12 | derzhavinsk
# Processing Record 38 of Set 12 | joetsu
# Processing Record 39 of Set 12 | khetri
# Processing Record 40 of Set 12 | bani walid
# Processing Record 41 of Set 12 | yarensk
# Processing Record 42 of Set 12 | beira
# Processing Record 43 of Set 12 | kalaleh
# Processing Record 44 of Set 12 | maymyo
# Processing Record 45 of Set 12 | akureyri
# Processing Record 46 of Set 12 | kholm
# Processing Record 47 of Set 12 | krasnaya polyana
# Processing Record 48 of Set 12 | cabras
# Processing Record 49 of Set 12 | zeya
# Processing Record 50 of Set 12 | naze
# Processing Record 1 of Set 13 | waddan
# Processing Record 2 of Set 13 | kelso
# Processing Record 3 of Set 13 | lena
# Processing Record 4 of Set 13 | fernley
# Processing Record 5 of Set 13 | diffa
# Processing Record 6 of Set 13 | mandera
# Processing Record 7 of Set 13 | praia
# Processing Record 8 of Set 13 | pointe michel
# Processing Record 9 of Set 13 | demmin
# Processing Record 10 of Set 13 | bonthe
# Processing Record 11 of Set 13 | pasni
# Processing Record 12 of Set 13 | naron
# Processing Record 13 of Set 13 | nyangao
# Processing Record 14 of Set 13 | antofagasta
# Processing Record 15 of Set 13 | sijunjung
# Processing Record 16 of Set 13 | nouadhibou
# Processing Record 17 of Set 13 | kandrian
# Processing Record 18 of Set 13 | chinsali
# Processing Record 19 of Set 13 | vrangel
# Processing Record 20 of Set 13 | dudinka
# Processing Record 21 of Set 13 | sintereag
# Processing Record 22 of Set 13 | bodden town
# Processing Record 23 of Set 13 | gamba
# Processing Record 24 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 25 of Set 13 | washougal
# Processing Record 26 of Set 13 | severomuysk
# Processing Record 27 of Set 13 | kijang
# Processing Record 28 of Set 13 | margate
# Processing Record 29 of Set 13 | dunkirk
# Processing Record 30 of Set 13 | port moresby
# Processing Record 31 of Set 13 | teya
# Processing Record 32 of Set 13 | raga
# Processing Record 33 of Set 13 | vanino
# Processing Record 34 of Set 13 | maniitsoq
# Processing Record 35 of Set 13 | kalabo
# Processing Record 36 of Set 13 | vila velha
# Processing Record 37 of Set 13 | ulaanbaatar
# Processing Record 38 of Set 13 | hovd
# Processing Record 39 of Set 13 | nouakchott
# Processing Record 40 of Set 13 | gurupa
# Processing Record 41 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 42 of Set 13 | jacqueville
# Processing Record 43 of Set 13 | santiago de cao
# Processing Record 44 of Set 13 | dolores
# Processing Record 45 of Set 13 | comodoro rivadavia
# Processing Record 46 of Set 13 | shetpe
# Processing Record 47 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 48 of Set 13 | monchegorsk
# Processing Record 49 of Set 13 | porto belo
# Processing Record 50 of Set 13 | yizheng
# Processing Record 1 of Set 14 | bowen
# Processing Record 2 of Set 14 | ostrovnoy
# Processing Record 3 of Set 14 | oranjemund
# Processing Record 4 of Set 14 | lufilufi
# Processing Record 5 of Set 14 | pacifica
# Processing Record 6 of Set 14 | ixtapa
# Processing Record 7 of Set 14 | baherden
# Processing Record 8 of Set 14 | micheweni
# Processing Record 9 of Set 14 | murdochville
# Processing Record 10 of Set 14 | igarka
# Processing Record 11 of Set 14 | kidal
# Processing Record 12 of Set 14 | mabaruma
# Processing Record 13 of Set 14 | yenotayevka
# Processing Record 14 of Set 14 | safford
# Processing Record 15 of Set 14 | kansay
# City not found. Skipping...
# Processing Record 16 of Set 14 | aksu
# Processing Record 17 of Set 14 | vila franca do campo
# Processing Record 18 of Set 14 | sambava
# Processing Record 19 of Set 14 | basar
# Processing Record 20 of Set 14 | daokou
# Processing Record 21 of Set 14 | birpur
# Processing Record 22 of Set 14 | mega
# Processing Record 23 of Set 14 | sobolevo
# Processing Record 24 of Set 14 | acapulco
# Processing Record 25 of Set 14 | bilibino
# Processing Record 26 of Set 14 | presidencia roque saenz pena
# Processing Record 27 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 28 of Set 14 | susanville
# Processing Record 29 of Set 14 | sistranda
# Processing Record 30 of Set 14 | albion
# Processing Record 31 of Set 14 | disraeli
# Processing Record 32 of Set 14 | barao de melgaco
# Processing Record 33 of Set 14 | antsohihy
# Processing Record 34 of Set 14 | kjollefjord
# Processing Record 35 of Set 14 | kruisfontein
# Processing Record 36 of Set 14 | gat
# Processing Record 37 of Set 14 | punta alta
# Processing Record 38 of Set 14 | dafeng
# Processing Record 39 of Set 14 | lusambo
# Processing Record 40 of Set 14 | guajara-mirim
# City not found. Skipping...
# Processing Record 41 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 42 of Set 14 | grande-riviere
# City not found. Skipping...
# Processing Record 43 of Set 14 | ippy
# Processing Record 44 of Set 14 | san jose de guanipa
# Processing Record 45 of Set 14 | bahia blanca
# Processing Record 46 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 14 | luganville
# Processing Record 48 of Set 14 | buritizeiro
# Processing Record 49 of Set 14 | tevriz
# Processing Record 50 of Set 14 | artesia
# Processing Record 1 of Set 15 | trinidad
# Processing Record 2 of Set 15 | shakhtinsk
# Processing Record 3 of Set 15 | klaksvik
# Processing Record 4 of Set 15 | bogorodskoye
# Processing Record 5 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 15 | banda aceh
# Processing Record 7 of Set 15 | tingi
# Processing Record 8 of Set 15 | jaggayyapeta
# Processing Record 9 of Set 15 | agadir
# Processing Record 10 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 11 of Set 15 | rybinsk
# Processing Record 12 of Set 15 | nagato
# Processing Record 13 of Set 15 | miranda
# Processing Record 14 of Set 15 | quebec
# Processing Record 15 of Set 15 | zlobin
# Processing Record 16 of Set 15 | ciudad bolivar
# Processing Record 17 of Set 15 | sawtell
# Processing Record 18 of Set 15 | mansfield
# Processing Record 19 of Set 15 | kunzelsau
# Processing Record 20 of Set 15 | faranah
# Processing Record 21 of Set 15 | yerofey pavlovich
# Processing Record 22 of Set 15 | pitimbu
# Processing Record 23 of Set 15 | westpunt
# City not found. Skipping...
# Processing Record 24 of Set 15 | ambilobe
# Processing Record 25 of Set 15 | hermosillo
# Processing Record 26 of Set 15 | tanjong karang
# City not found. Skipping...
# Processing Record 27 of Set 15 | horki
# Processing Record 28 of Set 15 | tigil
# Processing Record 29 of Set 15 | rivera
# Processing Record 30 of Set 15 | kasane
# Processing Record 31 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 15 | nova olimpia
# Processing Record 33 of Set 15 | acopiara
# Processing Record 34 of Set 15 | taoudenni
# Processing Record 35 of Set 15 | ust-ishim
# Processing Record 36 of Set 15 | kysyl-syr
# Processing Record 37 of Set 15 | college
# Processing Record 38 of Set 15 | pueblo nuevo
# Processing Record 39 of Set 15 | bayshore gardens
# Processing Record 40 of Set 15 | dong hoi
# Processing Record 41 of Set 15 | umkomaas
# Processing Record 42 of Set 15 | kautokeino
# Processing Record 43 of Set 15 | huron
# Processing Record 44 of Set 15 | erenhot
# Processing Record 45 of Set 15 | atherton
# Processing Record 46 of Set 15 | oranjestad
# Processing Record 47 of Set 15 | renqiu
# Processing Record 48 of Set 15 | suicheng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Hobart -42.88  147.33     73.99        39           0        6.93
# 1  Yellowknife  62.46 -114.35     -2.99        76          20       10.29
# 2  Otjiwarongo -20.46   16.65     73.40        55          53        2.24
# 3      Taiyuan  37.87  112.56     28.40        68         100        2.24
# 4      Ushuaia -54.80  -68.30     39.20        69          40        5.82
# 5   Bredasdorp -34.53   20.04     62.60        72         100        9.17
# 6        Pevek  69.70  170.31     11.77        92          64        4.27
# 7        Price  39.60 -110.81     28.40        33           1        4.70
# 8      Albanel  48.88  -72.45     33.80        96          79        4.70
# 9     Saldanha -33.01   17.94     59.00        82         100        6.93
#
#   Country Current Description                 Date
# 0      AU           clear sky  2020-11-28 02:16:01
# 1      CA          few clouds  2020-11-28 02:19:14
# 2      NA       broken clouds  2020-11-28 02:19:14
# 3      CN                haze  2020-11-28 02:19:14
# 4      AR    scattered clouds  2020-11-28 02:17:21
# 5      ZA     overcast clouds  2020-11-28 02:19:14
# 6      RU       broken clouds  2020-11-28 02:19:14
# 7      US           clear sky  2020-11-28 02:19:14
# 8      CA       broken clouds  2020-11-28 02:19:15
# 9      ZA     overcast clouds  2020-11-28 02:14:52

# %%
new_coloum_order =["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_coloum_order]
city_data_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hobart      AU -42.88  147.33     73.99        39           0
# 1  Yellowknife      CA  62.46 -114.35     -2.99        76          20
# 2  Otjiwarongo      NA -20.46   16.65     73.40        55          53
# 3      Taiyuan      CN  37.87  112.56     28.40        68         100
# 4      Ushuaia      AR -54.80  -68.30     39.20        69          40
#
#    Wind Speed Current Description
# 0        6.93           clear sky
# 1       10.29          few clouds
# 2        2.24       broken clouds
# 3        2.24                haze
# 4        5.82    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
